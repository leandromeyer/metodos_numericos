# %%
# QEWP (P01CH03)
## EFICIENT CODE
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.random.randn(100)
plt.plot(x)
plt.show()

# %%
## WITH FOR LOOP
ts_length = 100
ϵ_values = [] # Empty list
for i in range(ts_length):
    e = np.random.randn()
    ϵ_values.append(e)

plt.plot(ϵ_values)
plt.show()

# %%
# append() is a method, which is a function "attached to" and object (p.43)
# CODE BLOCK (é identificado por recuo; o padrão do python é 4 espaços); no exemplo acima:
# e = np.random.randn()
# ϵ_values.append(e)

# %%
# WITH WHILE LOOP
ts_length = 100
ϵ_values = []
i=0
while i < ts_length:
    e = np.random.randn()
    ϵ_values.append(e)
    i = i + 1 # CAN BE REPLACED BY 'i += 1'
    
plt.plot(ϵ_values)
plt.show()

# %%
# WITH A FUNCTION
def generate_data(n):
    ϵ_values = []
    for i in range(n):
        e = np.random.randn()
        ϵ_values.append(e)
    return ϵ_values

data = generate_data(100)
plt.plot(data)
plt.show()

# %%
# IMPROVING THE FUNCTION (conditions)
def generate_data(n, generator_type):
    ϵ_values = []
    for i in range(n):
        if generator_type == 'U':
            e = np.random.uniform(0,1)
        else:
            e = np.random.randn()
        ϵ_values.append(e)
    return ϵ_values

data = generate_data(100, 'U')
plt.plot(data)
plt.show()

# %%
# LIST COMPREHENSIONS
animals = ['dog', 'cat', 'bird']
plurals = [animal + 's' for animal in animals]
plurals
# Out:
# ['dogs', 'cats', 'birds']

# %%
range(8)
doubles = [2 * x for x in range(8)]
doubles
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]
